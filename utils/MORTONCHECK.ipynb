# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import UnivariateSpline
import emmaf as emma
# %matplotlib notebook
plt.rcParams['figure.figsize'] = (8.0,8.0)
# Out:
# /home/daubert/anaconda3/lib/python3.4/site-packages/IPython/kernel/__init__.py:13: ShimWarning: The `IPython.kernel` package has been deprecated. You should import from ipykernel or jupyter_client instead.
#   "You should import from ipykernel or jupyter_client instead.", ShimWarning)

# %%
field=emma.Grid()

# %%
field.load('./dump.dat')

# %%
np.min(field.data)
# Out:
# 1.7597728

# %%
plt.figure()
plt.plot(field.data[12,12,:])
# Out:
# /home/daubert/anaconda3/lib/python3.4/site-packages/matplotlib/pyplot.py:424: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# <img src="data:image/png;base64,...">

# %%
field2=emma.Grid()
field2.load('./dump.dat')

# %%
plt.figure()
plt.imshow(field2.data[14,:,:],interpolation='none')
# Out:
# /home/daubert/anaconda3/lib/python3.4/site-packages/matplotlib/pyplot.py:424: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# <img src="data:image/png;base64,...">

# %%
plt.figure()
plt.imshow(field.data[14,:,:],interpolation='none')
# Out:
# /home/daubert/anaconda3/lib/python3.4/site-packages/matplotlib/pyplot.py:424: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# <img src="data:image/png;base64,...">

# %%
field2=emma.Grid()
field2.load('./dump.dat')

# %%
plt.figure()
plt.imshow(field2.data[14,:,:],interpolation='none')
# Out:
# /home/daubert/anaconda3/lib/python3.4/site-packages/matplotlib/pyplot.py:424: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# <img src="data:image/png;base64,...">

# %%
plt.figure()
plt.imshow(f1[32,:,:],interpolation='none')
# Out:
# //anaconda/lib/python3.4/site-packages/matplotlib/pyplot.py:424: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# <img src="data:image/png;base64,...">

# %%
plt.figure()
plt.imshow(f1.data[32,:,:],interpolation='none')
# Out:
# //anaconda/lib/python3.4/site-packages/matplotlib/pyplot.py:424: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# <img src="data:image/png;base64,...">
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-90-321285c2ac60> in <module>()
#       1 plt.figure()
# ----> 2 plt.imshow(f1.data[32,:,:],interpolation='none')
#
# TypeError: invalid indexing of 0-dim memory

# %%
plt.figure()
plt.plot(field.data[32,:,32])
# Out:
# //anaconda/lib/python3.4/site-packages/matplotlib/pyplot.py:424: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# <img src="data:image/png;base64,...">

# %%
f1=np.copy(field.data)

# %%
f=open('data/grid_x/x.00000.p00000',"rb")
ncelltot=np.fromfile(f,dtype=np.int32,count=1)
#ncelltot=ncell[0]*ncell[1]*ncell[2]
time=np.fromfile(f,dtype=np.float32,count=1)[0]
limits=np.fromfile(f,dtype=np.float32,count=6)
data=np.fromfile(f,dtype=np.float32,count=ncelltot)
f.close

x=np.copy(data)

f=open('grid_grid_y/grid_y.00000.p00000',"rb")
ncelltot=np.fromfile(f,dtype=np.int32,count=1)
#ncelltot=ncell[0]*ncell[1]*ncell[2]
time=np.fromfile(f,dtype=np.float32,count=1)[0]
limits=np.fromfile(f,dtype=np.float32,count=6)
data=np.fromfile(f,dtype=np.float32,count=ncelltot)
f.close

y=np.copy(data)


f=open('grid_grid_z/grid_z.00000.p00000',"rb")
ncelltot=np.fromfile(f,dtype=np.int32,count=1)
#ncelltot=ncell[0]*ncell[1]*ncell[2]
time=np.fromfile(f,dtype=np.float32,count=1)[0]
limits=np.fromfile(f,dtype=np.float32,count=6)
data=np.fromfile(f,dtype=np.float32,count=ncelltot)
f.close

z=np.copy(data)
# Out:
# //anaconda/lib/python3.4/site-packages/ipykernel/__main__.py:6: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
# //anaconda/lib/python3.4/site-packages/ipykernel/__main__.py:16: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
# //anaconda/lib/python3.4/site-packages/ipykernel/__main__.py:27: DeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future

# %%
plt.figure()
plt.scatter(x,y)
# Out:
# <img src="data:image/png;base64,...">

# %%
1./4
# Out:
# 0.25

# %%
limits
# Out:
# array([ 0.,  1.,  0.,  1.,  0.,  1.], dtype=float32)

# %%
ncelltot
# Out:
# array([64], dtype=int32)
